# %%
# !mkdir result

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np
import time
from copy import deepcopy
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load CIFAR10

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
partition = {'train': trainset, 'val':valset, 'test':testset}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Model Structure

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}

class CNN(nn.Module):
    def __init__(self, model_code, in_channels, out_dim, fc_layer, hid_dim, act, use_bn, dropout, use_he):
        super(CNN, self).__init__()

        self.model_code = model_code
        self.in_channels = in_channels
        self.out_dim = out_dim
        self.fc_layer = fc_layer
        self.hid_dim = hid_dim
        self.use_bn = use_bn
        self.dropout = dropout
        self.HE = use_he
        
        if act == 'relu':
            self.act = nn.ReLU()
        elif act == 'tanh':
            self.act = nn.Tanh()
        elif act == 'sigmoid':
            self.act = nn.Sigmoid()
        else:
            raise ValueError('no valid activation function selected')

        self.layers = self._make_layers()
        self.fc = self._make_fc_layers()
        
        if self.HE:
            self._initialize_weights()
        
    def forward(self, x):
        x = self.layers(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
    def _make_layers(self):
        layers = []
        for x in cfg[self.model_code]:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels=self.in_channels, out_channels=x, kernel_size=3, stride=1, padding=1)]
                layers += [self.act]
                if self.use_bn:
                    layers += [nn.BatchNorm2d(x)]
                self.in_channels = x  
        return nn.Sequential(*layers)

    def _make_fc_layers(self):
        fc_layers = []
        fc_layers.append(nn.Linear(512, self.hid_dim))
        fc_layers.append(self.act)
        if self.dropout > 0:
            fc_layers.append(nn.Dropout(self.dropout))
        
        for _ in range(self.fc_layer):
            fc_layers.append(nn.Linear(self.hid_dim, self.hid_dim))
            if self.use_bn:
                fc_layers.append(nn.BatchNorm1d(self.hid_dim))
            fc_layers.append(self.act)
            if self.dropout > 0:
                fc_layers.append(nn.Dropout(self.dropout))

        fc_layers.append(nn.Linear(self.hid_dim, self.out_dim))
        return nn.Sequential(*fc_layers)

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                nn.init.constant_(m.bias, 0)

# %% [markdown]
# ## Train, Validation, Test

# %%
def train(net, partition, optimizer, criterion, args):
    trainloader = torch.utils.data.DataLoader(partition['train'], 
                                              batch_size=args.train_batch_size, 
                                              shuffle=True, num_workers=2)
    net.train()

    correct = 0
    total = 0
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        optimizer.zero_grad() # [21.01.05 오류 수정] 매 Epoch 마다 .zero_grad()가 실행되는 것을 매 iteration 마다 실행되도록 수정했습니다. 

        # get the inputs
        inputs, labels = data     
        inputs = inputs.cuda()
        labels = labels.cuda()
        outputs = net(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = train_loss / len(trainloader)
    train_acc = 100 * correct / total
    return net, train_loss, train_acc

# %%
def validate(net, partition, criterion, args):
    valloader = torch.utils.data.DataLoader(partition['val'], 
                                            batch_size=args.test_batch_size, 
                                            shuffle=False, num_workers=2)
    net.eval()

    correct = 0
    total = 0
    val_loss = 0 
    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            outputs = net(images)

            loss = criterion(outputs, labels)
            
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(valloader)
        val_acc = 100 * correct / total
    return val_loss, val_acc

# %%
def test(net, partition, args):
    testloader = torch.utils.data.DataLoader(partition['test'], 
                                             batch_size=args.test_batch_size, 
                                             shuffle=False, num_workers=2)
    net.eval()
    
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()

            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total
    return test_acc

# %%
def experiment(partition, args):

    
    net = CNN(model_code = args.model_code,
              in_channels = args.in_channels,
              out_dim = args.out_dim,
              fc_layer = args.fc_layer,
              hid_dim = args.hid_dim,
              act = args.act,
              use_bn = args.use_bn,
              dropout = args.dropout,
              use_he = args.use_he)
              
    
    
    net.cuda()
    print('{} parameters'.format(sum(p.numel() for p in net.parameters() if p.requires_grad)))
    criterion = nn.CrossEntropyLoss()
    if args.optim == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
        
    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        net, train_loss, train_acc = train(net, partition, optimizer, criterion, args)
        val_loss, val_acc = validate(net, partition, criterion, args)
        te = time.time()
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        
        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.2f}/{:2.2f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))
        
    test_acc = test(net, partition, args)    
    
    result = {}
    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['train_acc'] = train_acc
    result['val_acc'] = val_acc
    result['test_acc'] = test_acc
    return vars(args), result

# %% [markdown]
# ## Save Experiment result

# %%
import hashlib
import json
from os import listdir
from os.path import isfile, join
import pandas as pd

def save_exp_result(setting, result):
    exp_name = setting['exp_name']
    del setting['epoch']
    del setting['test_batch_size']

    hash_key = hashlib.sha1(str(setting).encode()).hexdigest()[:6]
    filename = './result/{}-{}.json'.format(exp_name, hash_key)
    result.update(setting)
    with open(filename, 'w') as f:
        json.dump(result, f)

    
def load_exp_result(exp_name):
    dir_path = './result'
    filenames = [f for f in listdir(dir_path) if isfile(join(dir_path, f)) if '.json' in f]
    list_result = []
    for filename in filenames:
        if exp_name in filename:
            with open(join(dir_path, filename), 'r') as infile:
                results = json.load(infile)
                list_result.append(results)
    df = pd.DataFrame(list_result) # .drop(columns=[])
    return df

# %% [markdown]
# ## Visualization

# %%
def plot_acc(var1, var2, df):

    fig, ax = plt.subplots(1, 3)
    fig.set_size_inches(15, 6)
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})

    sns.barplot(x=var1, y='train_acc', hue=var2, data=df, ax=ax[0])
    sns.barplot(x=var1, y='val_acc', hue=var2, data=df, ax=ax[1])
    sns.barplot(x=var1, y='test_acc', hue=var2, data=df, ax=ax[2])
    
    ax[0].set_title('Train Accuracy')
    ax[1].set_title('Validation Accuracy')
    ax[2].set_title('Test Accuracy')

    
def plot_loss_variation(var1, var2, df, **kwargs):

    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_losses = list(row.train_losses)[0]
            val_losses = list(row.val_losses)[0]

            for epoch, train_loss in enumerate(train_losses):
                list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_loss in enumerate(val_losses):
                list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'loss', marker='.')
    g.add_legend()
    g.fig.suptitle('Train loss vs Val loss')
    plt.tight_layout()
   


def plot_acc_variation(var1, var2, df, **kwargs):
    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_accs = list(row.train_accs)[0]
            val_accs = list(row.val_accs)[0]
            test_acc = list(row.test_acc)[0]

            for epoch, train_acc in enumerate(train_accs):
                list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_acc in enumerate(val_accs):
                list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

    def show_acc(x, y, metric, **kwargs):
        plt.scatter(x, y, alpha=0.3, s=1)
        metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
        plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
    g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

    g.add_legend()
    g.fig.suptitle('Train Accuracy vs Val Accuracy')
    plt.tight_layout()

# %% [markdown]
# ## Experiment 1

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp1_lr_model_code"

# ====== Model ====== #
#args.model_code = 'VGG11'
args.in_channels = 3
args.out_dim = 10
args.fc_layer = 3
args.hid_dim = 100
args.act = 'relu'
args.dropout = 0.3

# ====== Regularization ======= #
args.l2 = 0.00001
args.use_bn = True

# ====== Optimizer & Training ====== #
args.optim = 'Adam'
#args.lr = 0.0015
args.epoch = 10

args.train_batch_size = 512
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'lr'
name_var2 = 'model_code'
list_var1 = [0.0005]
list_var2 = ['VGG11', 'VGG16']


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(exp_name='exp1_lr_model_code', in_channels=3, out_dim=10, fc_layer=3, hid_dim=100, act='relu', dropout=0.3, l2=1e-05, use_bn=True, optim='Adam', epoch=10, train_batch_size=512, test_batch_size=1024, lr=0.0005, model_code='VGG11')
# 9309194 parameters
# Epoch 0, Acc(train/val): 24.21/36.39, Loss(train/val) 1.97/1.65. Took 15.57 sec
# Epoch 1, Acc(train/val): 41.16/46.12, Loss(train/val) 1.53/1.45. Took 15.59 sec
# Epoch 2, Acc(train/val): 51.82/50.79, Loss(train/val) 1.27/1.38. Took 15.61 sec
# Epoch 3, Acc(train/val): 60.89/62.45, Loss(train/val) 1.08/1.10. Took 15.60 sec
# Epoch 4, Acc(train/val): 69.13/66.79, Loss(train/val) 0.91/1.00. Took 15.59 sec
# Epoch 5, Acc(train/val): 74.37/67.98, Loss(train/val) 0.79/0.92. Took 15.63 sec
# Epoch 6, Acc(train/val): 77.52/65.36, Loss(train/val) 0.71/1.20. Took 15.76 sec
# Epoch 7, Acc(train/val): 81.72/73.01, Loss(train/val) 0.60/0.90. Took 15.79 sec
# Epoch 8, Acc(train/val): 83.33/75.45, Loss(train/val) 0.55/0.82. Took 15.62 sec
# Epoch 9, Acc(train/val): 86.27/76.32, Loss(train/val) 0.46/0.78. Took 15.78 sec
# Namespace(exp_name='exp1_lr_model_code', in_channels=3, out_dim=10, fc_layer=3, hid_dim=100, act='relu', dropout=0.3, l2=1e-05, use_bn=True, optim='Adam', epoch=10, train_batch_size=512, test_batch_size=1024, lr=0.0005, model_code='VGG16')
# 14806346 parameters
# Epoch 0, Acc(train/val): 19.19/20.47, Loss(train/val) 2.08/2.00. Took 20.30 sec
# Epoch 1, Acc(train/val): 29.59/33.10, Loss(train/val) 1.71/1.69. Took 20.58 sec
# Epoch 2, Acc(train/val): 40.47/42.44, Loss(train/val) 1.51/1.53. Took 20.43 sec
# Epoch 3, Acc(train/val): 49.60/49.65, Loss(train/val) 1.32/1.49. Took 20.13 sec
# Epoch 4, Acc(train/val): 58.95/62.13, Loss(train/val) 1.12/1.05. Took 20.25 sec
# Epoch 5, Acc(train/val): 64.03/56.31, Loss(train/val) 0.99/1.26. Took 20.22 sec
# Epoch 6, Acc(train/val): 67.67/60.78, Loss(train/val) 0.88/1.14. Took 20.40 sec
# Epoch 7, Acc(train/val): 71.57/66.48, Loss(train/val) 0.78/0.95. Took 20.37 sec
# Epoch 8, Acc(train/val): 76.19/72.28, Loss(train/val) 0.70/0.87. Took 20.20 sec
# Epoch 9, Acc(train/val): 80.56/65.98, Loss(train/val) 0.61/1.20. Took 20.15 sec

# %%
df = load_exp_result('exp1_lr_model_code')
df = df.loc[df['optim'] == 'Adam' ,:]
var1 = 'model_code'
var2 = 'lr'
plot_acc(var1, var2, df_sub)

# %%
plot_loss_variation(var1, var2, df)

# %%
plot_acc_variation(var1, var2, df)

# %% [markdown]
# ## Experiment 2

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp2_fc_layer_dropout"

# ====== Model ====== #
#args.model_code = 'VGG11'
args.in_channels = 3
args.out_dim = 10
#args.fc_layer = 3
args.hid_dim = 100
args.act = 'relu'
#args.dropout = 0.3

# ====== Regularization ======= #
args.l2 = 0.00001
args.use_bn = True

# ====== Optimizer & Training ====== #
args.optim = 'Adam'
args.lr = 0.0005
args.epoch = 10
args.model_code = 'VGG11'

args.train_batch_size = 512
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'dropout'
name_var2 = 'fc_layer'
list_var1 = [0,0.1,0.3,0.5]
list_var2 = [1,2,3]


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0, fc_layer=1)
# 9288594 parameters
# Epoch 0, Acc(train/val): 52.54/56.20, Loss(train/val) 1.37/1.24. Took 15.72 sec
# Epoch 1, Acc(train/val): 69.83/64.00, Loss(train/val) 0.89/1.04. Took 15.59 sec
# Epoch 2, Acc(train/val): 77.02/69.36, Loss(train/val) 0.68/0.91. Took 15.63 sec
# Epoch 3, Acc(train/val): 82.77/70.97, Loss(train/val) 0.51/0.86. Took 15.56 sec
# Epoch 4, Acc(train/val): 87.28/73.36, Loss(train/val) 0.39/0.81. Took 15.59 sec
# Epoch 5, Acc(train/val): 90.52/73.70, Loss(train/val) 0.29/0.84. Took 15.60 sec
# Epoch 6, Acc(train/val): 93.21/70.14, Loss(train/val) 0.21/1.03. Took 15.59 sec
# Epoch 7, Acc(train/val): 94.53/64.95, Loss(train/val) 0.17/1.32. Took 15.57 sec
# Epoch 8, Acc(train/val): 96.66/76.35, Loss(train/val) 0.11/0.83. Took 15.61 sec
# Epoch 9, Acc(train/val): 97.14/76.03, Loss(train/val) 0.09/0.88. Took 15.60 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0, fc_layer=2)
# 9298894 parameters
# Epoch 0, Acc(train/val): 49.74/52.08, Loss(train/val) 1.45/1.37. Took 15.59 sec
# Epoch 1, Acc(train/val): 68.49/57.92, Loss(train/val) 0.92/1.31. Took 15.59 sec
# Epoch 2, Acc(train/val): 76.43/65.33, Loss(train/val) 0.71/1.06. Took 15.80 sec
# Epoch 3, Acc(train/val): 81.44/69.03, Loss(train/val) 0.55/0.94. Took 15.75 sec
# Epoch 4, Acc(train/val): 85.59/71.95, Loss(train/val) 0.43/0.87. Took 15.84 sec
# Epoch 5, Acc(train/val): 89.75/74.29, Loss(train/val) 0.32/0.86. Took 15.81 sec
# Epoch 6, Acc(train/val): 92.45/69.04, Loss(train/val) 0.23/1.07. Took 16.19 sec
# Epoch 7, Acc(train/val): 94.07/76.71, Loss(train/val) 0.18/0.80. Took 15.98 sec
# Epoch 8, Acc(train/val): 95.38/73.03, Loss(train/val) 0.14/0.98. Took 16.01 sec
# Epoch 9, Acc(train/val): 97.48/77.05, Loss(train/val) 0.08/0.84. Took 15.57 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0, fc_layer=3)
# 9309194 parameters
# Epoch 0, Acc(train/val): 47.25/47.28, Loss(train/val) 1.51/1.46. Took 15.97 sec
# Epoch 1, Acc(train/val): 67.45/67.63, Loss(train/val) 0.95/0.93. Took 15.74 sec
# Epoch 2, Acc(train/val): 75.49/68.45, Loss(train/val) 0.72/0.94. Took 16.03 sec
# Epoch 3, Acc(train/val): 80.11/70.39, Loss(train/val) 0.60/0.90. Took 15.77 sec
# Epoch 4, Acc(train/val): 84.64/72.23, Loss(train/val) 0.46/0.85. Took 15.58 sec
# Epoch 5, Acc(train/val): 88.42/73.21, Loss(train/val) 0.36/0.85. Took 15.82 sec
# Epoch 6, Acc(train/val): 90.57/69.02, Loss(train/val) 0.29/1.07. Took 15.81 sec
# Epoch 7, Acc(train/val): 93.42/74.62, Loss(train/val) 0.21/0.86. Took 15.80 sec
# Epoch 8, Acc(train/val): 95.05/74.22, Loss(train/val) 0.16/0.92. Took 15.80 sec
# Epoch 9, Acc(train/val): 95.68/74.09, Loss(train/val) 0.14/0.96. Took 15.82 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.1, fc_layer=1)
# 9288594 parameters
# Epoch 0, Acc(train/val): 48.74/48.41, Loss(train/val) 1.48/1.48. Took 15.77 sec
# Epoch 1, Acc(train/val): 68.27/67.09, Loss(train/val) 0.95/0.96. Took 16.29 sec
# Epoch 2, Acc(train/val): 76.04/69.21, Loss(train/val) 0.72/0.92. Took 15.74 sec
# Epoch 3, Acc(train/val): 81.46/71.83, Loss(train/val) 0.56/0.82. Took 15.40 sec
# Epoch 4, Acc(train/val): 85.10/73.84, Loss(train/val) 0.46/0.80. Took 15.77 sec
# Epoch 5, Acc(train/val): 88.29/76.00, Loss(train/val) 0.36/0.76. Took 15.76 sec
# Epoch 6, Acc(train/val): 91.31/75.60, Loss(train/val) 0.28/0.83. Took 15.78 sec
# Epoch 7, Acc(train/val): 93.29/67.11, Loss(train/val) 0.21/1.23. Took 15.67 sec
# Epoch 8, Acc(train/val): 95.03/70.87, Loss(train/val) 0.16/1.13. Took 15.99 sec
# Epoch 9, Acc(train/val): 95.47/75.40, Loss(train/val) 0.15/0.93. Took 16.02 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.1, fc_layer=2)
# 9298894 parameters
# Epoch 0, Acc(train/val): 44.36/50.53, Loss(train/val) 1.56/1.39. Took 15.58 sec
# Epoch 1, Acc(train/val): 64.61/60.09, Loss(train/val) 1.03/1.16. Took 15.59 sec
# Epoch 2, Acc(train/val): 73.44/68.34, Loss(train/val) 0.80/0.94. Took 15.77 sec
# Epoch 3, Acc(train/val): 78.69/69.91, Loss(train/val) 0.65/0.91. Took 15.67 sec
# Epoch 4, Acc(train/val): 83.00/73.75, Loss(train/val) 0.52/0.82. Took 15.76 sec
# Epoch 5, Acc(train/val): 85.94/74.98, Loss(train/val) 0.43/0.77. Took 15.81 sec
# Epoch 6, Acc(train/val): 89.14/64.89, Loss(train/val) 0.34/1.30. Took 16.03 sec
# Epoch 7, Acc(train/val): 91.17/71.67, Loss(train/val) 0.28/1.01. Took 15.89 sec
# Epoch 8, Acc(train/val): 93.67/75.71, Loss(train/val) 0.21/0.87. Took 16.07 sec
# Epoch 9, Acc(train/val): 93.83/76.26, Loss(train/val) 0.20/0.85. Took 15.72 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.1, fc_layer=3)
# 9309194 parameters
# Epoch 0, Acc(train/val): 38.50/50.97, Loss(train/val) 1.69/1.36. Took 16.03 sec
# Epoch 1, Acc(train/val): 59.76/59.13, Loss(train/val) 1.16/1.17. Took 15.60 sec
# Epoch 2, Acc(train/val): 69.96/62.99, Loss(train/val) 0.89/1.10. Took 15.58 sec
# Epoch 3, Acc(train/val): 75.64/70.29, Loss(train/val) 0.73/0.90. Took 15.86 sec
# Epoch 4, Acc(train/val): 79.91/70.85, Loss(train/val) 0.61/0.92. Took 15.56 sec
# Epoch 5, Acc(train/val): 83.32/73.99, Loss(train/val) 0.52/0.80. Took 15.56 sec
# Epoch 6, Acc(train/val): 85.69/73.47, Loss(train/val) 0.45/0.86. Took 15.60 sec
# Epoch 7, Acc(train/val): 88.39/72.08, Loss(train/val) 0.37/0.98. Took 15.77 sec
# Epoch 8, Acc(train/val): 91.06/71.78, Loss(train/val) 0.29/0.98. Took 15.79 sec
# Epoch 9, Acc(train/val): 92.36/75.79, Loss(train/val) 0.25/0.87. Took 15.83 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.3, fc_layer=1)
# 9288594 parameters
# Epoch 0, Acc(train/val): 43.09/46.68, Loss(train/val) 1.61/1.51. Took 15.76 sec
# Epoch 1, Acc(train/val): 62.43/59.01, Loss(train/val) 1.12/1.15. Took 15.67 sec
# Epoch 2, Acc(train/val): 71.08/65.92, Loss(train/val) 0.88/1.00. Took 15.59 sec
# Epoch 3, Acc(train/val): 77.30/68.80, Loss(train/val) 0.71/0.95. Took 15.76 sec
# Epoch 4, Acc(train/val): 80.86/73.03, Loss(train/val) 0.61/0.82. Took 15.78 sec
# Epoch 5, Acc(train/val): 84.78/75.62, Loss(train/val) 0.50/0.76. Took 15.81 sec
# Epoch 6, Acc(train/val): 87.66/72.84, Loss(train/val) 0.40/0.88. Took 15.83 sec
# Epoch 7, Acc(train/val): 89.83/76.91, Loss(train/val) 0.34/0.76. Took 15.97 sec
# Epoch 8, Acc(train/val): 91.64/73.91, Loss(train/val) 0.28/0.93. Took 15.78 sec
# Epoch 9, Acc(train/val): 93.40/74.88, Loss(train/val) 0.23/0.94. Took 15.83 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.3, fc_layer=2)
# 9298894 parameters
# Epoch 0, Acc(train/val): 32.10/43.51, Loss(train/val) 1.84/1.48. Took 15.76 sec
# Epoch 1, Acc(train/val): 52.74/60.30, Loss(train/val) 1.34/1.16. Took 15.83 sec
# Epoch 2, Acc(train/val): 64.43/61.83, Loss(train/val) 1.06/1.08. Took 16.00 sec
# Epoch 3, Acc(train/val): 71.39/61.98, Loss(train/val) 0.88/1.21. Took 15.87 sec
# Epoch 4, Acc(train/val): 76.37/66.31, Loss(train/val) 0.75/1.04. Took 15.69 sec
# Epoch 5, Acc(train/val): 79.31/71.18, Loss(train/val) 0.66/0.92. Took 15.59 sec
# Epoch 6, Acc(train/val): 82.61/74.64, Loss(train/val) 0.57/0.80. Took 15.94 sec
# Epoch 7, Acc(train/val): 85.49/67.77, Loss(train/val) 0.48/1.19. Took 15.85 sec
# Epoch 8, Acc(train/val): 87.59/69.58, Loss(train/val) 0.42/1.06. Took 15.79 sec
# Epoch 9, Acc(train/val): 89.10/72.95, Loss(train/val) 0.37/0.96. Took 15.96 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.3, fc_layer=3)
# 9309194 parameters
# Epoch 0, Acc(train/val): 23.74/28.62, Loss(train/val) 2.02/1.89. Took 15.86 sec
# Epoch 1, Acc(train/val): 37.95/47.17, Loss(train/val) 1.57/1.40. Took 15.62 sec
# Epoch 2, Acc(train/val): 48.63/52.43, Loss(train/val) 1.33/1.27. Took 15.75 sec
# Epoch 3, Acc(train/val): 58.39/48.11, Loss(train/val) 1.14/1.71. Took 15.67 sec
# Epoch 4, Acc(train/val): 66.68/67.29, Loss(train/val) 0.97/0.95. Took 15.79 sec
# Epoch 5, Acc(train/val): 72.58/66.99, Loss(train/val) 0.83/1.00. Took 16.14 sec
# Epoch 6, Acc(train/val): 75.82/72.99, Loss(train/val) 0.74/0.83. Took 15.78 sec
# Epoch 7, Acc(train/val): 79.51/70.90, Loss(train/val) 0.64/0.93. Took 15.87 sec
# Epoch 8, Acc(train/val): 82.38/72.37, Loss(train/val) 0.57/0.94. Took 16.04 sec
# Epoch 9, Acc(train/val): 84.38/75.77, Loss(train/val) 0.51/0.82. Took 15.96 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.5, fc_layer=1)
# 9288594 parameters
# Epoch 0, Acc(train/val): 30.28/35.75, Loss(train/val) 1.88/1.72. Took 15.82 sec
# Epoch 1, Acc(train/val): 49.91/56.15, Loss(train/val) 1.41/1.21. Took 15.61 sec
# Epoch 2, Acc(train/val): 60.98/65.90, Loss(train/val) 1.15/1.01. Took 15.56 sec
# Epoch 3, Acc(train/val): 68.28/65.90, Loss(train/val) 0.97/1.08. Took 15.60 sec
# Epoch 4, Acc(train/val): 73.38/68.74, Loss(train/val) 0.83/0.92. Took 15.95 sec
# Epoch 5, Acc(train/val): 77.55/69.91, Loss(train/val) 0.72/0.93. Took 15.62 sec
# Epoch 6, Acc(train/val): 81.24/70.40, Loss(train/val) 0.62/0.96. Took 15.83 sec
# Epoch 7, Acc(train/val): 83.70/76.70, Loss(train/val) 0.54/0.75. Took 15.74 sec
# Epoch 8, Acc(train/val): 86.14/71.63, Loss(train/val) 0.47/0.99. Took 15.67 sec
# Epoch 9, Acc(train/val): 86.94/76.12, Loss(train/val) 0.45/0.83. Took 15.95 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.5, fc_layer=2)
# 9298894 parameters
# Epoch 0, Acc(train/val): 20.46/31.53, Loss(train/val) 2.09/1.79. Took 15.88 sec
# Epoch 1, Acc(train/val): 30.98/39.17, Loss(train/val) 1.73/1.55. Took 15.67 sec
# Epoch 2, Acc(train/val): 37.81/44.39, Loss(train/val) 1.53/1.46. Took 16.00 sec
# Epoch 3, Acc(train/val): 44.90/50.72, Loss(train/val) 1.39/1.33. Took 15.74 sec
# Epoch 4, Acc(train/val): 52.75/60.83, Loss(train/val) 1.26/1.13. Took 15.80 sec
# Epoch 5, Acc(train/val): 60.02/60.00, Loss(train/val) 1.13/1.17. Took 15.83 sec
# Epoch 6, Acc(train/val): 63.59/59.37, Loss(train/val) 1.03/1.23. Took 15.59 sec
# Epoch 7, Acc(train/val): 67.14/61.78, Loss(train/val) 0.94/1.24. Took 15.75 sec
# Epoch 8, Acc(train/val): 70.04/67.64, Loss(train/val) 0.86/0.95. Took 15.61 sec
# Epoch 9, Acc(train/val): 73.16/60.35, Loss(train/val) 0.77/1.41. Took 15.80 sec
# Namespace(exp_name='exp2_fc_layer_dropout', in_channels=3, out_dim=10, hid_dim=100, act='relu', l2=1e-05, use_bn=True, optim='Adam', lr=0.0005, epoch=10, model_code='VGG11', train_batch_size=512, test_batch_size=1024, dropout=0.5, fc_layer=3)
# 9309194 parameters
# Epoch 0, Acc(train/val): 14.32/12.57, Loss(train/val) 2.25/2.27. Took 15.80 sec
# Epoch 1, Acc(train/val): 19.41/16.08, Loss(train/val) 1.95/2.14. Took 15.61 sec
# Epoch 2, Acc(train/val): 23.62/30.89, Loss(train/val) 1.81/1.71. Took 15.59 sec
# Epoch 3, Acc(train/val): 27.77/31.76, Loss(train/val) 1.69/1.62. Took 15.64 sec
# Epoch 4, Acc(train/val): 33.30/42.04, Loss(train/val) 1.59/1.51. Took 15.57 sec
# Epoch 5, Acc(train/val): 39.55/40.65, Loss(train/val) 1.48/1.64. Took 15.79 sec
# Epoch 6, Acc(train/val): 43.80/46.38, Loss(train/val) 1.39/1.45. Took 15.81 sec
# Epoch 7, Acc(train/val): 48.47/52.26, Loss(train/val) 1.32/1.26. Took 15.74 sec
# Epoch 8, Acc(train/val): 52.20/48.36, Loss(train/val) 1.23/1.38. Took 15.82 sec
# Epoch 9, Acc(train/val): 56.07/56.15, Loss(train/val) 1.13/1.20. Took 15.84 sec

# %%
df = load_exp_result('exp2_fc_layer_dropout')
var1 = 'dropout'
var2 = 'fc_layer'
plot_acc(var1, var2, df)

# %%
plot_loss_variation(var1, var2, df)

# %%
plot_acc_variation(var1, var2, df)

# %% [markdown]
# ## Experiment 3

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp3_optim_use_he"

# ====== Model ====== #
args.model_code = 'VGG11'
args.in_channels = 3
args.out_dim = 10
args.fc_layer = 1
args.hid_dim = 100
args.act = 'relu'
args.dropout = 0.5
#args.use_he = True

# ====== Regularization ======= #
args.l2 = 0.00001
args.use_bn = True

# ====== Optimizer & Training ====== #
#args.optim = 'Adam'
args.lr = 0.0005
args.epoch = 10
args.model_code = 'VGG11'

args.train_batch_size = 512
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'optim'
name_var2 = 'use_he'
list_var1 = ['RMSprop', 'Adam']
list_var2 = [False, True]


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(exp_name='exp3_optim_use_he', model_code='VGG11', in_channels=3, out_dim=10, fc_layer=1, hid_dim=100, act='relu', dropout=0.5, l2=1e-05, use_bn=True, lr=0.0005, epoch=10, train_batch_size=512, test_batch_size=1024, optim='RMSprop', use_he=False)
# 9288594 parameters
# Epoch 0, Acc(train/val): 29.36/26.40, Loss(train/val) 1.86/2.00. Took 16.23 sec
# Epoch 1, Acc(train/val): 47.94/30.29, Loss(train/val) 1.42/2.05. Took 16.02 sec
# Epoch 2, Acc(train/val): 60.62/51.12, Loss(train/val) 1.17/1.39. Took 16.25 sec
# Epoch 3, Acc(train/val): 70.06/53.72, Loss(train/val) 0.94/1.45. Took 15.94 sec
# Epoch 4, Acc(train/val): 75.84/57.99, Loss(train/val) 0.77/1.28. Took 15.81 sec
# Epoch 5, Acc(train/val): 80.75/50.49, Loss(train/val) 0.64/1.92. Took 15.96 sec
# Epoch 6, Acc(train/val): 84.59/63.11, Loss(train/val) 0.53/1.53. Took 15.64 sec
# Epoch 7, Acc(train/val): 88.00/56.62, Loss(train/val) 0.42/1.87. Took 15.84 sec
# Epoch 8, Acc(train/val): 90.31/68.94, Loss(train/val) 0.35/1.17. Took 15.78 sec
# Epoch 9, Acc(train/val): 92.42/68.42, Loss(train/val) 0.28/1.28. Took 15.79 sec
# Namespace(exp_name='exp3_optim_use_he', model_code='VGG11', in_channels=3, out_dim=10, fc_layer=1, hid_dim=100, act='relu', dropout=0.5, l2=1e-05, use_bn=True, lr=0.0005, epoch=10, train_batch_size=512, test_batch_size=1024, optim='RMSprop', use_he=True)
# 9288594 parameters
# Epoch 0, Acc(train/val): 23.00/24.16, Loss(train/val) 2.69/2.11. Took 15.71 sec
# Epoch 1, Acc(train/val): 35.02/30.49, Loss(train/val) 1.96/1.94. Took 15.73 sec
# Epoch 2, Acc(train/val): 44.23/32.84, Loss(train/val) 1.69/1.97. Took 15.93 sec
# Epoch 3, Acc(train/val): 51.88/34.04, Loss(train/val) 1.47/2.24. Took 15.99 sec
# Epoch 4, Acc(train/val): 58.17/48.90, Loss(train/val) 1.30/1.61. Took 15.91 sec
# Epoch 5, Acc(train/val): 64.47/42.81, Loss(train/val) 1.13/1.79. Took 15.83 sec
# Epoch 6, Acc(train/val): 69.84/62.31, Loss(train/val) 0.96/1.24. Took 15.83 sec
# Epoch 7, Acc(train/val): 75.45/42.25, Loss(train/val) 0.81/2.57. Took 15.97 sec
# Epoch 8, Acc(train/val): 77.97/63.74, Loss(train/val) 0.72/1.33. Took 15.79 sec
# Epoch 9, Acc(train/val): 82.97/60.58, Loss(train/val) 0.57/1.60. Took 16.01 sec
# Namespace(exp_name='exp3_optim_use_he', model_code='VGG11', in_channels=3, out_dim=10, fc_layer=1, hid_dim=100, act='relu', dropout=0.5, l2=1e-05, use_bn=True, lr=0.0005, epoch=10, train_batch_size=512, test_batch_size=1024, optim='Adam', use_he=False)
# 9288594 parameters
# Epoch 0, Acc(train/val): 38.85/54.78, Loss(train/val) 1.74/1.31. Took 16.03 sec
# Epoch 1, Acc(train/val): 59.41/60.65, Loss(train/val) 1.24/1.13. Took 16.10 sec
# Epoch 2, Acc(train/val): 68.53/67.44, Loss(train/val) 1.00/0.95. Took 15.86 sec
# Epoch 3, Acc(train/val): 75.21/71.48, Loss(train/val) 0.81/0.85. Took 16.02 sec
# Epoch 4, Acc(train/val): 80.14/73.03, Loss(train/val) 0.67/0.83. Took 15.99 sec
# Epoch 5, Acc(train/val): 84.08/76.95, Loss(train/val) 0.55/0.74. Took 16.26 sec
# Epoch 6, Acc(train/val): 86.94/76.88, Loss(train/val) 0.46/0.76. Took 15.94 sec
# Epoch 7, Acc(train/val): 89.67/75.86, Loss(train/val) 0.38/0.82. Took 15.61 sec
# Epoch 8, Acc(train/val): 91.35/76.84, Loss(train/val) 0.32/0.83. Took 15.78 sec
# Epoch 9, Acc(train/val): 92.79/77.40, Loss(train/val) 0.27/0.85. Took 15.56 sec
# Namespace(exp_name='exp3_optim_use_he', model_code='VGG11', in_channels=3, out_dim=10, fc_layer=1, hid_dim=100, act='relu', dropout=0.5, l2=1e-05, use_bn=True, lr=0.0005, epoch=10, train_batch_size=512, test_batch_size=1024, optim='Adam', use_he=True)
# 9288594 parameters
# Epoch 0, Acc(train/val): 21.75/41.16, Loss(train/val) 3.12/1.82. Took 15.99 sec
# Epoch 1, Acc(train/val): 33.67/52.42, Loss(train/val) 2.06/1.61. Took 15.66 sec
# Epoch 2, Acc(train/val): 44.20/56.38, Loss(train/val) 1.74/1.38. Took 15.63 sec
# Epoch 3, Acc(train/val): 51.37/57.93, Loss(train/val) 1.51/1.24. Took 15.92 sec
# Epoch 4, Acc(train/val): 57.15/66.17, Loss(train/val) 1.30/1.05. Took 15.80 sec
# Epoch 5, Acc(train/val): 64.44/67.57, Loss(train/val) 1.10/0.97. Took 15.79 sec
# Epoch 6, Acc(train/val): 69.44/68.80, Loss(train/val) 0.94/0.95. Took 16.00 sec
# Epoch 7, Acc(train/val): 74.79/69.49, Loss(train/val) 0.80/0.98. Took 15.77 sec
# Epoch 8, Acc(train/val): 78.09/71.79, Loss(train/val) 0.70/0.91. Took 16.02 sec
# Epoch 9, Acc(train/val): 82.32/71.70, Loss(train/val) 0.60/0.95. Took 15.76 sec

# %%
df = load_exp_result("exp3_optim_use_he")
var1 = 'optim'
var2 = 'use_he'
plot_acc(var1, var2, df)

# %%
plot_loss_variation(var1, var2, df)

# %%
plot_acc_variation(var1, var2, df)

# %% [markdown]
# Adam optimizer와 HE initilaization을 활용한 실험은 학습이 덜 된 것으로 보임.
# epoch을 늘리면 정확도가 향상될 것으로 기대됨.
